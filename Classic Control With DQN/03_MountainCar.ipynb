# %% [markdown]
# # DQN with TensorFlow & gym
# <br>
# In this notebook we'll build our very first Deep Q-Network with TensorFlow deep learning framework and OpenAI gym <a href='https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py'>MountainCar-v0</a> environment. <br><br><br>

# %%
import gym
import random
import numpy as np
import tensorflow as tf
from tensorflow.contrib.layers import fully_connected

# %%
tf.reset_default_graph()

# %%
class DQN:
    def __init__(self, input_shape:object = None, action_size:object = None, scope:object = None) -> object:

        if input_shape is None:
            input_shape = [None, 4]
        self.max_size = 1000000
        self.mem = []

        with tf.variable_scope(scope):
            self.scope = scope
            self.input_shape = input_shape
            self.action_size = action_size
            self.initializer = tf.contrib.layers.variance_scaling_initializer()

            self.states = tf.placeholder(shape=input_shape, dtype=tf.float32)
            self.actions = tf.placeholder(shape=[None], dtype=tf.int32)
            self.actions_onehot = tf.one_hot(
                self.actions, action_size, dtype=tf.float32)

            fc1 = fully_connected(self.states, 
                                  512, 
                                  activation_fn=tf.nn.relu,
                                  weights_initializer=self.initializer)
            fc2 = fully_connected(fc1, 
                                  256, 
                                  activation_fn=tf.nn.relu,
                                  weights_initializer=self.initializer)
            fc3 = fully_connected(fc2, 
                                  256, 
                                  activation_fn=tf.nn.relu,
                                  weights_initializer=self.initializer)
            self.q = fully_connected(fc3, 
                                    action_size, 
                                    activation_fn=None,
                                    weights_initializer=self.initializer)
            

            self.target_q = tf.placeholder(shape=[None], dtype=tf.float32)
            self.responsible_output = tf.reduce_sum(tf.multiply(
                self.q, self.actions_onehot), axis=1, keep_dims=False)
            self.loss = tf.reduce_mean(
                tf.square(self.responsible_output - self.target_q))

            self.update_model = tf.train.AdamOptimizer().minimize(self.loss)

    def action(self, sess, state):
        q = sess.run(self.q, feed_dict={self.states: state[np.newaxis, ...]})
        return np.argmax(q)

    def train(self, sess, batch, learning_rate, tnet):
        assert len(batch) > 0
        states = np.vstack(batch[:, 0])
        actions = np.array(batch[:, 1])
        rewards = batch[:, 2]
        next_states = np.vstack(batch[:, 3])
        dones = batch[:, 4]

        next_q = sess.run(tnet.q, feed_dict={tnet.states: next_states})

        next_q = rewards + (1. - dones.astype(np.float32)) * \
            learning_rate * np.amax(next_q, axis=1, keepdims=False)

        sess.run(self.update_model, feed_dict={self.states: states,
                                               self.actions: actions,
                                               self.target_q: next_q})

    def add(self, element):
        self.mem.append(element)

        if len(self.mem) > self.max_size:
            self.mem.pop(0)

    def sample(self, size):
        size = min(size, len(self.mem))
        return random.sample(self.mem, size)


    def update_graph(self, from_graph:object, to_graph:object) -> object:
        from_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, from_graph)
        to_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, to_graph)
    
        holder = []
        for from_var, to_var in zip(from_vars, to_vars):
            holder.append(to_var.assign(from_var))
        return holder

# %%
target_update = 200
epsilon_max = 1.0
epsilon_min = 0.01
epsilon_decay = 0.001
learning_rate = 0.99
batch_size = 64
EPISODES = 300



env = gym.make('MountainCar-v0')
action_size = env.action_space.n
input_shape = [None] + list(env.observation_space.shape)

time_step = 0.0
epsilon = epsilon_max

Q_Network = DQN(input_shape=input_shape,
                action_size=action_size, scope='Q_Network')
Train_Network = DQN(input_shape=input_shape,
                    action_size=action_size, scope='Train_Network')

update_ops = Q_Network.update_graph('Q_Network', 'Train_Network')

saver = tf.train.Saver()
score = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(EPISODES):
        total_reward = 0
        state = env.reset()
        while True:
            env.render()
            if np.random.rand() < epsilon:
                action = np.random.randint(action_size)
            else:
                action = Q_Network.action(sess, state)
            next_state, reward, done, _ = env.step(action)
            total_reward += reward

            Q_Network.add([state, action, reward, next_state, done])

            time_step += 1.
            epsilon = epsilon_min + \
                (epsilon_max - epsilon_min) * \
                np.exp(-epsilon_decay * time_step)

            batch = np.array(Q_Network.sample(batch_size))
            Q_Network.train(sess, batch, learning_rate, Train_Network)

            state = np.copy(next_state)

            if int(time_step) % target_update == 0:
                sess.run(update_ops)
                saver.save(sess, "./checkpoints/MountainCar_DQN.ckpt")

            if done:
                print('Epoch:', epoch, 'Total Rewards:', total_reward)
                score.append(total_reward)
                break
                
    

env.close()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARNING:tensorflow:From <ipython-input-3-c0a89b3f30a5>:40: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Epoch: 0 Total Rewards: -200.0
# Epoch: 1 Total Rewards: -200.0
# Epoch: 2 Total Rewards: -200.0
# Epoch: 3 Total Rewards: -200.0
# Epoch: 4 Total Rewards: -200.0
# Epoch: 5 Total Rewards: -200.0
# Epoch: 6 Total Rewards: -200.0
# Epoch: 7 Total Rewards: -200.0
# Epoch: 8 Total Rewards: -200.0
# Epoch: 9 Total Rewards: -200.0
# Epoch: 10 Total Rewards: -200.0
# Epoch: 11 Total Rewards: -200.0
# Epoch: 12 Total Rewards: -200.0
# Epoch: 13 Total Rewards: -200.0
# Epoch: 14 Total Rewards: -200.0
# Epoch: 15 Total Rewards: -200.0
# Epoch: 16 Total Rewards: -200.0
# Epoch: 17 Total Rewards: -200.0
# Epoch: 18 Total Rewards: -200.0
# Epoch: 19 Total Rewards: -200.0
# Epoch: 20 Total Rewards: -170.0
# Epoch: 21 Total Rewards: -200.0
# Epoch: 22 Total Rewards: -200.0
# Epoch: 23 Total Rewards: -169.0
# Epoch: 24 Total Rewards: -200.0
# Epoch: 25 Total Rewards: -200.0
# Epoch: 26 Total Rewards: -200.0
# Epoch: 27 Total Rewards: -200.0
# Epoch: 28 Total Rewards: -200.0
# Epoch: 29 Total Rewards: -200.0
# Epoch: 30 Total Rewards: -200.0
# Epoch: 31 Total Rewards: -180.0
# Epoch: 32 Total Rewards: -200.0
# Epoch: 33 Total Rewards: -200.0
# Epoch: 34 Total Rewards: -155.0
# Epoch: 35 Total Rewards: -200.0
# Epoch: 36 Total Rewards: -200.0
# Epoch: 37 Total Rewards: -200.0
# Epoch: 38 Total Rewards: -200.0
# Epoch: 39 Total Rewards: -157.0
# Epoch: 40 Total Rewards: -200.0
# Epoch: 41 Total Rewards: -173.0
# Epoch: 42 Total Rewards: -200.0
# Epoch: 43 Total Rewards: -200.0
# Epoch: 44 Total Rewards: -200.0
# Epoch: 45 Total Rewards: -200.0
# Epoch: 46 Total Rewards: -200.0
# Epoch: 47 Total Rewards: -200.0
# Epoch: 48 Total Rewards: -200.0
# Epoch: 49 Total Rewards: -154.0
# Epoch: 50 Total Rewards: -200.0
# Epoch: 51 Total Rewards: -200.0
# Epoch: 52 Total Rewards: -193.0
# Epoch: 53 Total Rewards: -200.0
# Epoch: 54 Total Rewards: -145.0
# Epoch: 55 Total Rewards: -133.0
# Epoch: 56 Total Rewards: -200.0
# Epoch: 57 Total Rewards: -155.0
# Epoch: 58 Total Rewards: -157.0
# Epoch: 59 Total Rewards: -148.0
# Epoch: 60 Total Rewards: -133.0
# Epoch: 61 Total Rewards: -176.0
# Epoch: 62 Total Rewards: -125.0
# Epoch: 63 Total Rewards: -200.0
# Epoch: 64 Total Rewards: -158.0
# Epoch: 65 Total Rewards: -144.0
# Epoch: 66 Total Rewards: -157.0
# Epoch: 67 Total Rewards: -153.0
# Epoch: 68 Total Rewards: -145.0
# Epoch: 69 Total Rewards: -142.0
# Epoch: 70 Total Rewards: -160.0
# Epoch: 71 Total Rewards: -155.0
# Epoch: 72 Total Rewards: -175.0
# Epoch: 73 Total Rewards: -161.0
# Epoch: 74 Total Rewards: -152.0
# Epoch: 75 Total Rewards: -164.0
# Epoch: 76 Total Rewards: -172.0
# Epoch: 77 Total Rewards: -197.0
# Epoch: 78 Total Rewards: -163.0
# Epoch: 79 Total Rewards: -165.0
# Epoch: 80 Total Rewards: -169.0
# Epoch: 81 Total Rewards: -156.0
# Epoch: 82 Total Rewards: -105.0
# Epoch: 83 Total Rewards: -174.0
# Epoch: 84 Total Rewards: -161.0
# Epoch: 85 Total Rewards: -106.0
# Epoch: 86 Total Rewards: -91.0
# Epoch: 87 Total Rewards: -191.0
# Epoch: 88 Total Rewards: -200.0
# Epoch: 89 Total Rewards: -162.0
# Epoch: 90 Total Rewards: -178.0
# Epoch: 91 Total Rewards: -200.0
# Epoch: 92 Total Rewards: -158.0
# Epoch: 93 Total Rewards: -174.0
# Epoch: 94 Total Rewards: -150.0
# Epoch: 95 Total Rewards: -200.0
# Epoch: 96 Total Rewards: -200.0
# Epoch: 97 Total Rewards: -151.0
# Epoch: 98 Total Rewards: -86.0
# Epoch: 99 Total Rewards: -154.0
# Epoch: 100 Total Rewards: -200.0
# Epoch: 101 Total Rewards: -200.0
# Epoch: 102 Total Rewards: -91.0
# Epoch: 103 Total Rewards: -146.0
# Epoch: 104 Total Rewards: -179.0
# Epoch: 105 Total Rewards: -87.0
# Epoch: 106 Total Rewards: -153.0
# Epoch: 107 Total Rewards: -89.0
# Epoch: 108 Total Rewards: -184.0
# Epoch: 109 Total Rewards: -200.0
# Epoch: 110 Total Rewards: -167.0
# Epoch: 111 Total Rewards: -139.0
# Epoch: 112 Total Rewards: -156.0
# Epoch: 113 Total Rewards: -166.0
# Epoch: 114 Total Rewards: -200.0
# Epoch: 115 Total Rewards: -163.0
# Epoch: 116 Total Rewards: -200.0
# Epoch: 117 Total Rewards: -145.0
# Epoch: 118 Total Rewards: -154.0
# Epoch: 119 Total Rewards: -88.0
# Epoch: 120 Total Rewards: -160.0
# Epoch: 121 Total Rewards: -183.0
# Epoch: 122 Total Rewards: -200.0
# Epoch: 123 Total Rewards: -86.0
# Epoch: 124 Total Rewards: -184.0
# Epoch: 125 Total Rewards: -92.0
# Epoch: 126 Total Rewards: -96.0
# Epoch: 127 Total Rewards: -145.0
# Epoch: 128 Total Rewards: -115.0
# Epoch: 129 Total Rewards: -85.0
# Epoch: 130 Total Rewards: -155.0
# Epoch: 131 Total Rewards: -113.0
# Epoch: 132 Total Rewards: -88.0
# Epoch: 133 Total Rewards: -113.0
# Epoch: 134 Total Rewards: -185.0
# Epoch: 135 Total Rewards: -153.0
# Epoch: 136 Total Rewards: -148.0
# Epoch: 137 Total Rewards: -158.0
# Epoch: 138 Total Rewards: -100.0
# Epoch: 139 Total Rewards: -156.0
# Epoch: 140 Total Rewards: -93.0
# Epoch: 141 Total Rewards: -104.0
# Epoch: 142 Total Rewards: -112.0
# Epoch: 143 Total Rewards: -87.0
# Epoch: 144 Total Rewards: -86.0
# Epoch: 145 Total Rewards: -86.0
# Epoch: 146 Total Rewards: -107.0
# Epoch: 147 Total Rewards: -112.0
# Epoch: 148 Total Rewards: -113.0
# Epoch: 149 Total Rewards: -141.0
# Epoch: 150 Total Rewards: -118.0
# Epoch: 151 Total Rewards: -129.0
# Epoch: 152 Total Rewards: -86.0
# Epoch: 153 Total Rewards: -159.0
# Epoch: 154 Total Rewards: -106.0
# Epoch: 155 Total Rewards: -111.0
# Epoch: 156 Total Rewards: -116.0
# Epoch: 157 Total Rewards: -111.0
# Epoch: 158 Total Rewards: -111.0
# Epoch: 159 Total Rewards: -144.0
# Epoch: 160 Total Rewards: -117.0
# Epoch: 161 Total Rewards: -90.0
# Epoch: 162 Total Rewards: -103.0
# Epoch: 163 Total Rewards: -108.0
# Epoch: 164 Total Rewards: -118.0
# Epoch: 165 Total Rewards: -110.0
# Epoch: 166 Total Rewards: -113.0
# Epoch: 167 Total Rewards: -109.0
# Epoch: 168 Total Rewards: -115.0
# Epoch: 169 Total Rewards: -117.0
# Epoch: 170 Total Rewards: -113.0
# Epoch: 171 Total Rewards: -117.0
# Epoch: 172 Total Rewards: -108.0
# Epoch: 173 Total Rewards: -120.0
# Epoch: 174 Total Rewards: -124.0
# Epoch: 175 Total Rewards: -122.0
# Epoch: 176 Total Rewards: -128.0
# Epoch: 177 Total Rewards: -130.0
# Epoch: 178 Total Rewards: -108.0
# Epoch: 179 Total Rewards: -116.0
# Epoch: 180 Total Rewards: -85.0
# Epoch: 181 Total Rewards: -200.0
# Epoch: 182 Total Rewards: -113.0
# Epoch: 183 Total Rewards: -124.0
# Epoch: 184 Total Rewards: -117.0
# Epoch: 185 Total Rewards: -134.0
# Epoch: 186 Total Rewards: -124.0
# Epoch: 187 Total Rewards: -119.0
# Epoch: 188 Total Rewards: -116.0
# Epoch: 189 Total Rewards: -114.0
# Epoch: 190 Total Rewards: -117.0
# Epoch: 191 Total Rewards: -126.0
# Epoch: 192 Total Rewards: -114.0
# Epoch: 193 Total Rewards: -107.0
# Epoch: 194 Total Rewards: -114.0
# Epoch: 195 Total Rewards: -120.0
# Epoch: 196 Total Rewards: -127.0
# Epoch: 197 Total Rewards: -122.0
# Epoch: 198 Total Rewards: -139.0
# Epoch: 199 Total Rewards: -123.0
# Epoch: 200 Total Rewards: -121.0
# Epoch: 201 Total Rewards: -119.0
# Epoch: 202 Total Rewards: -120.0
# Epoch: 203 Total Rewards: -135.0
# Epoch: 204 Total Rewards: -114.0
# Epoch: 205 Total Rewards: -115.0
# Epoch: 206 Total Rewards: -120.0
# Epoch: 207 Total Rewards: -108.0
# Epoch: 208 Total Rewards: -116.0
# Epoch: 209 Total Rewards: -118.0
# Epoch: 210 Total Rewards: -119.0
# Epoch: 211 Total Rewards: -130.0
# Epoch: 212 Total Rewards: -122.0
# Epoch: 213 Total Rewards: -137.0
# Epoch: 214 Total Rewards: -118.0
# Epoch: 215 Total Rewards: -115.0
# Epoch: 216 Total Rewards: -110.0
# Epoch: 217 Total Rewards: -116.0
# Epoch: 218 Total Rewards: -106.0
# Epoch: 219 Total Rewards: -92.0
# Epoch: 220 Total Rewards: -118.0
# Epoch: 221 Total Rewards: -112.0
# Epoch: 222 Total Rewards: -136.0
# Epoch: 223 Total Rewards: -117.0
# Epoch: 224 Total Rewards: -118.0
# Epoch: 225 Total Rewards: -118.0
# Epoch: 226 Total Rewards: -121.0
# Epoch: 227 Total Rewards: -87.0
# Epoch: 228 Total Rewards: -107.0
# Epoch: 229 Total Rewards: -109.0
# Epoch: 230 Total Rewards: -87.0
# Epoch: 231 Total Rewards: -88.0
# Epoch: 232 Total Rewards: -126.0
# Epoch: 233 Total Rewards: -148.0
# Epoch: 234 Total Rewards: -113.0
# Epoch: 235 Total Rewards: -155.0
# Epoch: 236 Total Rewards: -91.0
# Epoch: 237 Total Rewards: -94.0
# Epoch: 238 Total Rewards: -168.0
# Epoch: 239 Total Rewards: -102.0
# Epoch: 240 Total Rewards: -160.0
# Epoch: 241 Total Rewards: -88.0
# Epoch: 242 Total Rewards: -144.0
# Epoch: 243 Total Rewards: -89.0
# Epoch: 244 Total Rewards: -119.0
# Epoch: 245 Total Rewards: -106.0
# Epoch: 246 Total Rewards: -138.0
# Epoch: 247 Total Rewards: -156.0
# Epoch: 248 Total Rewards: -164.0
# Epoch: 249 Total Rewards: -90.0
# Epoch: 250 Total Rewards: -85.0
# Epoch: 251 Total Rewards: -188.0
# Epoch: 252 Total Rewards: -86.0
# Epoch: 253 Total Rewards: -164.0
# Epoch: 254 Total Rewards: -89.0
# Epoch: 255 Total Rewards: -97.0
# Epoch: 256 Total Rewards: -88.0
# Epoch: 257 Total Rewards: -141.0
# Epoch: 258 Total Rewards: -85.0
# Epoch: 259 Total Rewards: -167.0
# Epoch: 260 Total Rewards: -150.0
# Epoch: 261 Total Rewards: -160.0
# Epoch: 262 Total Rewards: -123.0
# Epoch: 263 Total Rewards: -87.0
# Epoch: 264 Total Rewards: -172.0
# Epoch: 265 Total Rewards: -97.0
# Epoch: 266 Total Rewards: -175.0
# Epoch: 267 Total Rewards: -169.0
# Epoch: 268 Total Rewards: -142.0
# Epoch: 269 Total Rewards: -176.0
# Epoch: 270 Total Rewards: -131.0
# Epoch: 271 Total Rewards: -88.0
# Epoch: 272 Total Rewards: -149.0
# Epoch: 273 Total Rewards: -88.0
# Epoch: 274 Total Rewards: -167.0
# Epoch: 275 Total Rewards: -89.0
# Epoch: 276 Total Rewards: -117.0
# Epoch: 277 Total Rewards: -153.0
# Epoch: 278 Total Rewards: -92.0
# Epoch: 279 Total Rewards: -87.0
# Epoch: 280 Total Rewards: -166.0
# Epoch: 281 Total Rewards: -133.0
# Epoch: 282 Total Rewards: -106.0
# Epoch: 283 Total Rewards: -146.0
# Epoch: 284 Total Rewards: -85.0
# Epoch: 285 Total Rewards: -105.0
# Epoch: 286 Total Rewards: -105.0
# Epoch: 287 Total Rewards: -106.0
# Epoch: 288 Total Rewards: -117.0
# Epoch: 289 Total Rewards: -118.0
# Epoch: 290 Total Rewards: -131.0
# Epoch: 291 Total Rewards: -94.0
# Epoch: 292 Total Rewards: -158.0
# Epoch: 293 Total Rewards: -144.0
# Epoch: 294 Total Rewards: -108.0
# Epoch: 295 Total Rewards: -121.0
# Epoch: 296 Total Rewards: -149.0
# Epoch: 297 Total Rewards: -102.0
# Epoch: 298 Total Rewards: -87.0
# Epoch: 299 Total Rewards: -110.0

# %%
score = np.array(score)
totla_epoch = len(score)

print("Total Epoch:", totla_epoch)
print("Min Reward:", score.min())
print("Max Reward:", score.max())
print("Average Reward:", score.mean())
print("Highest Performance:", score.max(), "Reached at:", np.argmax(score) + 1, "Episode")
# Out:
# Total Epoch: 300
# Min Reward: -200.0
# Max Reward: -85.0
# Average Reward: -142.53333333333333
# Highest Performance: -85.0 Reached at: 130 Episode

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(1, figsize=(18,10))
plt.grid(True)
plt.xlabel("Epoch")
plt.ylabel("Rewards")
plt.plot(range(totla_epoch), score)
plt.show()
